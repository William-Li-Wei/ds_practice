# %%
import numpy as np
import seaborn as sns

# %% [markdown]
# ---

# %% [markdown]
# # Binomial Distribution
#
# with parameters **n** and **p**, is the **discrete probability distribution** of the number of successes in a sequence of **n independent experiments**, each asking a yes–no question, and each with its own **boolean-valued outcome**.
#
# https://en.wikipedia.org/wiki/Binomial_distribution
#
# ### PMF
#
# The probability of getting exactly k successes in n independent Bernoulli trials:
# <img src="resources/binomial_pmf.png" alt="Drawing" style="width: 600px; margin-left: 4em"/>

# %% [markdown]
# ### CDF
#
# The cumulative distribution function can be expressed as:
# <img src="resources/binomial_cdf.png" alt="Drawing" style="width: 600px; margin-left: 4em"/>

# %% [markdown]
# ### Expected Value
#
# E(X) = np
#
# ### Variance
#
# Var(X) = np(1-P)
#
# ### Skewness and Kurtosis
#
# See above wiki page

# %%
# During Coronavirus, how many confirmed case shall a small supermarket expect every day?
# Given the local effected rate = 0.001 and Supermarket's daily volume = 60000
n, p = 6000, 0.001
bi_data = np.random.binomial(n, p, 1000)

# %%
sns.distplot(bi_data)

# %%
kwargs = {'cumulative': True}
sns.distplot(bi_data, hist_kws=kwargs, kde_kws=kwargs)

# %% [markdown]
# ---

# %% [markdown]
# # Geometric Distribution
#
# is the probability distribution of the number trials (X) needed to get one success.
#
# https://en.wikipedia.org/wiki/Geometric_distribution
#
# ### PMF
#
# <img src="resources/geometric_pmf.png" alt="Drawing" style="width: 100px; margin-left: 4em"/>

# %% [markdown]
# ### CDF
#
# <img src="resources/geometric_cdf.png" alt="Drawing" style="width: 100px; margin-left: 4em"/>
#
# ### Expected Value
#
# E(X) = 1 / p
#
# ### Variance
#
# Var(X) = (1 - p） / p^2
#
# ### Skewness and Kurtosis
#
# see above wiki page

# %%
# say in a gambling game, the probability of winning of each game p is 0.01
# how many plays are you expecting till the first win?
p = 0.01
geo_data = np.random.geometric(p, 1000)

# %%
sns.distplot(geo_data)

# %%
kwargs = {'cumulative': True}
sns.distplot(geo_data, hist_kws=kwargs, kde_kws=kwargs)
